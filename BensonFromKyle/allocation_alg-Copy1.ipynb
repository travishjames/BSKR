# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('df_concatenated_station_v3.csv') #import later
def get_top_50(grp):
    return grp.sort_values("IMPRESSIONS", ascending = False).head(50)

# %%
top50 = df.groupby('DAY')[["IMPRESSIONS", "STATION"]].apply(get_top_50).reset_index()

# %%
total_traffic = top50.groupby(['DAY'])['IMPRESSIONS'].sum().reset_index()

# %%
top50 = top50.merge(total_traffic, on = 'DAY', suffixes = ['_station', '_total'])

# %%
top50['density_score'] = top50['IMPRESSIONS_station'] / top50['IMPRESSIONS_total']

# %%
top50['slots'] = top50['density_score'].map(lambda val: round(val * 150))

# %%
total_slots = top50.groupby(['DAY'])[['density_score', 'slots']].sum().reset_index()

# %%
top50.groupby('DAY')['slots'].sum()
# Out:
# DAY
# 10    153
# 11    153
# 12    147
# 13    150
# 14    150
# 15    149
# 16    150
# Name: slots, dtype: float64

# %%
top50[top50.DAY==12]
# Out:
#      DAY  level_1  IMPRESSIONS_station          STATION  IMPRESSIONS_total  \
# 100   12      429               308789   34 ST-PENN STA            5059993
# 101   12     1612               277455  GRD CNTRL-42 ST            5059993
# 102   12      415               215529  34 ST-HERALD SQ            5059993
# 103   12      324               209552            23 ST            5059993
# 104   12      100               186565   14 ST-UNION SQ            5059993
# 105   12     2437               182168   TIMES SQ-42 ST            5059993
# 106   12      765               181054            86 ST            5059993
# 107   12     1563               177910        FULTON ST            5059993
# 108   12      478               157937  42 ST-PORT AUTH            5059993
# 109   12      597               137307            59 ST            5059993
# 110   12       65               131935           125 ST            5059993
# 111   12      604               128856   59 ST COLUMBUS            5059993
# 112   12     1241               124626      CHAMBERS ST            5059993
# 113   12     1192               122523         CANAL ST            5059993
# 114   12      793               120779            96 ST            5059993
# 115   12      506               117846   47-50 STS ROCK            5059993
# 116   12       93               107255            14 ST            5059993
# 117   12     1500               105922    FLUSHING-MAIN            5059993
# 118   12      366                96002            28 ST            5059993
# 119   12      681                93246            72 ST            5059993
# 120   12     2528                91326          WALL ST            5059993
# 121   12     1871                82737  LEXINGTON AV/53            5059993
# 122   12      471                82717  42 ST-BRYANT PK            5059993
# 123   12     1780                82105  JKSN HT-ROOSVLT            5059993
# 124   12      548                80273            50 ST            5059993
# 125   12     2507                79066   W 4 ST-WASH SQ            5059993
# 126   12      856                73951   ATL AV-BARCLAY            5059993
# 127   12     1745                72145   JAMAICA CENTER            5059993
# 128   12      709                72138            77 ST            5059993
# 129   12     1759                72103  JAY ST-METROTEC            5059993
# 130   12      667                68204             7 AV            5059993
# 131   12      107                66873           145 ST            5059993
# 132   12     1073                65046     BOROUGH HALL            5059993
# 133   12      723                64841             8 AV            5059993
# 134   12     1094                61819    BOWLING GREEN            5059993
# 135   12      653                60223   68ST-HUNTER CO            5059993
# 136   12     1262                59297        CHURCH AV            5059993
# 137   12     1808                54055      KEW GARDENS            5059993
# 138   12     1024                53494       BEDFORD AV            5059993
# 139   12      401                53493            33 ST            5059993
# 140   12     1591                52305         GRAND ST            5059993
# 141   12        9                51201           103 ST            5059993
# 142   12       44                50360           116 ST            5059993
# 143   12     1815                49574        KINGS HWY            5059993
# 144   12      926                49383  B'WAY-LAFAYETTE            5059993
# 145   12      527                48976       5 AV/53 ST            5059993
# 146   12      513                46101            49 ST            5059993
# 147   12      590                44958       57 ST-7 AV            5059993
# 148   12      149                43995  161/YANKEE STAD            5059993
# 149   12     1353                43978  CROWN HTS-UTICA            5059993
#
#      density_score  slots
# 100       0.061026      9
# 101       0.054833      8
# 102       0.042595      6
# 103       0.041413      6
# 104       0.036871      6
# 105       0.036002      5
# 106       0.035781      5
# 107       0.035160      5
# 108       0.031213      5
# 109       0.027136      4
# 110       0.026074      4
# 111       0.025466      4
# 112       0.024630      4
# 113       0.024214      4
# 114       0.023869      4
# 115       0.023290      3
# 116       0.021197      3
# 117       0.020933      3
# 118       0.018973      3
# 119       0.018428      3
# 120       0.018049      3
# 121       0.016351      2
# 122       0.016347      2
# 123       0.016226      2
# 124       0.015864      3
# 125       0.015626      2
# 126       0.014615      2
# 127       0.014258      2
# 128       0.014257      2
# 129       0.014250      2
# 130       0.013479      2
# 131       0.013216      2
# 132       0.012855      2
# 133       0.012814      3
# 134       0.012217      2
# 135       0.011902      3
# 136       0.011719      2
# 137       0.010683      2
# 138       0.010572      2
# 139       0.010572      2
# 140       0.010337      2
# 141       0.010119      2
# 142       0.009953      1
# 143       0.009797      1
# 144       0.009759      1
# 145       0.009679      1
# 146       0.009111      1
# 147       0.008885      1
# 148       0.008695      1
# 149       0.008691      1

# %%
top50.slots.loc[134]=2
top50.slots.loc[133]=3
top50.slots.loc[135]=3
top50.slots.loc[285]=3
top50.slots.loc[35]=1
top50.slots.loc[36]=1
top50.slots.loc[37]=1
top50.slots.loc[80]=1
top50.slots.loc[81]=1
top50.slots.loc[82]=1
# Out:
# /Users/kylemix/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
def duplicate_rows(df, countcol):
    for _, row in df.iterrows():
        for i in range(int(row[countcol])-1):
            # Append this row at the end of the DataFrame
            df = pd.concat(row)
        return df

# %%
tester = top50[['STATION','slots']][top50.DAY==12].copy(deep=True)
# tester.set_index('STATION', inplace = True)
duplicate_rows(tester,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-223-ec84e04a60be> in <module>()
#       1 tester = top50[['STATION','slots']][top50.DAY==12].copy(deep=True)
#       2 # tester.set_index('STATION', inplace = True)
# ----> 3 duplicate_rows(tester,1)
#
# <ipython-input-220-21173343efe5> in duplicate_rows(df, countcol)
#       3         for i in range(int(row[countcol])-1):
#       4             # Append this row at the end of the DataFrame
# ----> 5             df = pd.concat(row)
#       6         return df
#
# /Users/kylemix/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     810                        keys=keys, levels=levels, names=names,
#     811                        verify_integrity=verify_integrity,
# --> 812                        copy=copy)
#     813     return op.get_result()
#     814
#
# /Users/kylemix/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     825             raise TypeError('first argument must be an iterable of pandas '
#     826                             'objects, you passed an object of type '
# --> 827                             '"{0}"'.format(type(objs).__name__))
#     828
#     829         if join == 'outer':
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "Series"

# %%
performers = pd.read_csv('performer_dataset.csv')
performers.head()
performers = performers.sort_values(by='Performance_code')

# %%
from collections import defaultdict
def firstRound(day):
    filt = top50[['STATION','slots']][top50.DAY==day]
#     filt.set_index(['STATION','slots'])
    d= {k:v for k,v in zip(filt.STATION, filt.slots)}
    samplelist = [np.random.choice(performers.Performer_ID, replace=False) for p in performers.Performer_ID]
    newDict = defaultdict(list)
    for k,v in d.items():
        v=int(v)
        newValue = samplelist[:v]
        newDict[k]=newValue
        del samplelist[:v]
    return newDict

# %%
def make_frame(day):
    
    f = pd.DataFrame.from_dict(firstRound(day), orient = 'index').stack()
    frame =pd.DataFrame(f)
    frame.reset_index(1,drop=2,inplace=True)
    merger = top50[['STATION','IMPRESSIONS_station']][top50.DAY==day].copy(deep=True)
    merger.set_index('STATION', inplace=True)
    frame = frame.merge(merger,left_index=True,right_index=True)
    frame.reset_index(drop=True,inplace=True)
    frame.columns = ['Performer_ID','IMPRESSIONS_station']
 
    return frame

# %%
def run_1Week():
    df10 = make_frame(10)
    df11 = make_frame(11)
    df12 = make_frame(12)
    df13 = make_frame(13)
    df14 = make_frame(14)
    df15 = make_frame(15)
    df16 = make_frame(16)
    allTogether = pd.concat([df11,df12,df13,df14,df15,df16],axis =0)
    allTogether = allTogether.groupby('Performer_ID')['IMPRESSIONS_station'].sum().reset_index()
#     allTogether.set_index('Performer_ID',inplace = True)
    return allTogether

def run_1Month():                            
    week1 = run_1Week()
    week2 = run_1Week()
    week3 = run_1Week()
    week4 = run_1Week()
    month = week1.add(week2,axis='index').add(week3,axis='index').add(week4,axis='index')
    return month
month = run_1Month()
