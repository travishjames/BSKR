# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('df_concatenated_station_v3.csv') #import later
def get_top_50(grp):
    return grp.sort_values("IMPRESSIONS", ascending = False).head(50)

# %%
top50 = df.groupby('DAY')[["IMPRESSIONS", "STATION"]].apply(get_top_50).reset_index()

# %%
total_traffic = top50.groupby(['DAY'])['IMPRESSIONS'].sum().reset_index()

# %%
top50 = top50.merge(total_traffic, on = 'DAY', suffixes = ['_station', '_total'])

# %%
top50['density_score'] = top50['IMPRESSIONS_station'] / top50['IMPRESSIONS_total']

# %%
top50['slots'] = top50['density_score'].map(lambda val: round(val * 150))

# %%
total_slots = top50.groupby(['DAY'])[['density_score', 'slots']].sum().reset_index()

# %%
top50.groupby('DAY')['slots'].sum()
# Out:
# DAY
# 10    153.0
# 11    153.0
# 12    147.0
# 13    150.0
# 14    150.0
# 15    149.0
# 16    150.0
# Name: slots, dtype: float64

# %%
top50[top50.DAY==12]
# Out:
#      DAY  level_1  IMPRESSIONS_station          STATION  IMPRESSIONS_total  \
# 100   12      429             308789.0   34 ST-PENN STA          5059993.0
# 101   12     1612             277455.0  GRD CNTRL-42 ST          5059993.0
# 102   12      415             215529.0  34 ST-HERALD SQ          5059993.0
# 103   12      324             209552.0            23 ST          5059993.0
# 104   12      100             186565.0   14 ST-UNION SQ          5059993.0
# 105   12     2437             182168.0   TIMES SQ-42 ST          5059993.0
# 106   12      765             181054.0            86 ST          5059993.0
# 107   12     1563             177910.0        FULTON ST          5059993.0
# 108   12      478             157937.0  42 ST-PORT AUTH          5059993.0
# 109   12      597             137307.0            59 ST          5059993.0
# 110   12       65             131935.0           125 ST          5059993.0
# 111   12      604             128856.0   59 ST COLUMBUS          5059993.0
# 112   12     1241             124626.0      CHAMBERS ST          5059993.0
# 113   12     1192             122523.0         CANAL ST          5059993.0
# 114   12      793             120779.0            96 ST          5059993.0
# 115   12      506             117846.0   47-50 STS ROCK          5059993.0
# 116   12       93             107255.0            14 ST          5059993.0
# 117   12     1500             105922.0    FLUSHING-MAIN          5059993.0
# 118   12      366              96002.0            28 ST          5059993.0
# 119   12      681              93246.0            72 ST          5059993.0
# 120   12     2528              91326.0          WALL ST          5059993.0
# 121   12     1871              82737.0  LEXINGTON AV/53          5059993.0
# 122   12      471              82717.0  42 ST-BRYANT PK          5059993.0
# 123   12     1780              82105.0  JKSN HT-ROOSVLT          5059993.0
# 124   12      548              80273.0            50 ST          5059993.0
# 125   12     2507              79066.0   W 4 ST-WASH SQ          5059993.0
# 126   12      856              73951.0   ATL AV-BARCLAY          5059993.0
# 127   12     1745              72145.0   JAMAICA CENTER          5059993.0
# 128   12      709              72138.0            77 ST          5059993.0
# 129   12     1759              72103.0  JAY ST-METROTEC          5059993.0
# 130   12      667              68204.0             7 AV          5059993.0
# 131   12      107              66873.0           145 ST          5059993.0
# 132   12     1073              65046.0     BOROUGH HALL          5059993.0
# 133   12      723              64841.0             8 AV          5059993.0
# 134   12     1094              61819.0    BOWLING GREEN          5059993.0
# 135   12      653              60223.0   68ST-HUNTER CO          5059993.0
# 136   12     1262              59297.0        CHURCH AV          5059993.0
# 137   12     1808              54055.0      KEW GARDENS          5059993.0
# 138   12     1024              53494.0       BEDFORD AV          5059993.0
# 139   12      401              53493.0            33 ST          5059993.0
# 140   12     1591              52305.0         GRAND ST          5059993.0
# 141   12        9              51201.0           103 ST          5059993.0
# 142   12       44              50360.0           116 ST          5059993.0
# 143   12     1815              49574.0        KINGS HWY          5059993.0
# 144   12      926              49383.0  B'WAY-LAFAYETTE          5059993.0
# 145   12      527              48976.0       5 AV/53 ST          5059993.0
# 146   12      513              46101.0            49 ST          5059993.0
# 147   12      590              44958.0       57 ST-7 AV          5059993.0
# 148   12      149              43995.0  161/YANKEE STAD          5059993.0
# 149   12     1353              43978.0  CROWN HTS-UTICA          5059993.0
#
#      density_score  slots
# 100       0.061026    9.0
# 101       0.054833    8.0
# 102       0.042595    6.0
# 103       0.041413    6.0
# 104       0.036871    6.0
# 105       0.036002    5.0
# 106       0.035781    5.0
# 107       0.035160    5.0
# 108       0.031213    5.0
# 109       0.027136    4.0
# 110       0.026074    4.0
# 111       0.025466    4.0
# 112       0.024630    4.0
# 113       0.024214    4.0
# 114       0.023869    4.0
# 115       0.023290    3.0
# 116       0.021197    3.0
# 117       0.020933    3.0
# 118       0.018973    3.0
# 119       0.018428    3.0
# 120       0.018049    3.0
# 121       0.016351    2.0
# 122       0.016347    2.0
# 123       0.016226    2.0
# 124       0.015864    2.0
# 125       0.015626    2.0
# 126       0.014615    2.0
# 127       0.014258    2.0
# 128       0.014257    2.0
# 129       0.014250    2.0
# 130       0.013479    2.0
# 131       0.013216    2.0
# 132       0.012855    2.0
# 133       0.012814    2.0
# 134       0.012217    2.0
# 135       0.011902    2.0
# 136       0.011719    2.0
# 137       0.010683    2.0
# 138       0.010572    2.0
# 139       0.010572    2.0
# 140       0.010337    2.0
# 141       0.010119    2.0
# 142       0.009953    1.0
# 143       0.009797    1.0
# 144       0.009759    1.0
# 145       0.009679    1.0
# 146       0.009111    1.0
# 147       0.008885    1.0
# 148       0.008695    1.0
# 149       0.008691    1.0

# %%
top50.slots.loc[134]=2
top50.slots.loc[133]=3
top50.slots.loc[135]=3
top50.slots.loc[285]=3
top50.slots.loc[35]=1
top50.slots.loc[36]=1
top50.slots.loc[37]=1
top50.slots.loc[80]=1
top50.slots.loc[81]=1
top50.slots.loc[82]=1

# %%
def duplicate_rows(df, countcol):
    for _, row in df.iterrows():
        for i in range(int(row[countcol])-1):
            # Append this row at the end of the DataFrame
            df = pd.concat(row)
        return df

# %%
performers = pd.read_csv('performer_dataset.csv')
performers.head()
performers = performers.sort_values(by='Performance_code')

# %%
from collections import defaultdict
def firstRound(day):
    filt = top50[['STATION','slots']][top50.DAY==day]
#     filt.set_index(['STATION','slots'])
    d= {k:v for k,v in zip(filt.STATION, filt.slots)}
    samplelist = [np.random.choice(performers.Performer_ID, replace=False) for p in performers.Performer_ID]
    newDict = defaultdict(list)
    for k,v in d.items():
        v=int(v)
        newValue = samplelist[:v]
        newDict[k]=newValue
        del samplelist[:v]
    return newDict

# %%
def make_frame(day):
    
    f = pd.DataFrame.from_dict(firstRound(day), orient = 'index').stack()
    frame =pd.DataFrame(f)
#     slots = top50[['STATION','slots']][top50.DAY==day].copy(deep=True)
#     slots = slots.reset_index('STATION', inplace = True)
    frame.reset_index(1,drop=2,inplace=True)
    
    
    merger = top50[['STATION','IMPRESSIONS_station','slots']][top50.DAY==day].copy(deep=True)
    merger.set_index('STATION', inplace=True)
    frame = frame.merge(merger,left_index=True,right_index=True)
    frame.reset_index(drop=True,inplace=True)
    
    frame.columns = ['Performer_ID','IMPRESSIONS_station','slots']
    frame['perf_imp'] = frame.IMPRESSIONS_station / frame.slots
    return frame
make_frame(11)
# Out:
#      Performer_ID  IMPRESSIONS_station  slots      perf_imp
# 0            98.0              32321.0    1.0  32321.000000
# 1            70.0              33403.0    2.0  16701.500000
# 2            22.0              33403.0    2.0  16701.500000
# 3           119.0              82391.0    5.0  16478.200000
# 4           141.0              82391.0    5.0  16478.200000
# 5           110.0              82391.0    5.0  16478.200000
# 6             4.0              82391.0    5.0  16478.200000
# 7            98.0              82391.0    5.0  16478.200000
# 8            25.0              64430.0    4.0  16107.500000
# 9            74.0              64430.0    4.0  16107.500000
# 10           52.0              64430.0    4.0  16107.500000
# 11           96.0              64430.0    4.0  16107.500000
# 12           61.0             116360.0    7.0  16622.857143
# 13          143.0             116360.0    7.0  16622.857143
# 14          100.0             116360.0    7.0  16622.857143
# 15           47.0             116360.0    7.0  16622.857143
# 16          122.0             116360.0    7.0  16622.857143
# 17          137.0             116360.0    7.0  16622.857143
# 18           18.0             116360.0    7.0  16622.857143
# 19          127.0              49382.0    3.0  16460.666667
# 20           78.0              49382.0    3.0  16460.666667
# 21           89.0              49382.0    3.0  16460.666667
# 22          122.0              32912.0    1.0  32912.000000
# 23          132.0              26471.0    2.0  13235.500000
# 24           93.0              26471.0    2.0  13235.500000
# 25          103.0              26598.0    2.0  13299.000000
# 26          100.0              26598.0    2.0  13299.000000
# 27          143.0              86325.0    5.0  17265.000000
# 28          132.0              86325.0    5.0  17265.000000
# 29           35.0              86325.0    5.0  17265.000000
# ..            ...                  ...    ...           ...
# 120          73.0              77479.0    4.0  19369.750000
# 121          56.0              77479.0    4.0  19369.750000
# 122         114.0              35123.0    2.0  17561.500000
# 123         130.0              35123.0    2.0  17561.500000
# 124         131.0              91585.0    5.0  18317.000000
# 125          62.0              91585.0    5.0  18317.000000
# 126         141.0              91585.0    5.0  18317.000000
# 127          39.0              91585.0    5.0  18317.000000
# 128         141.0              91585.0    5.0  18317.000000
# 129         131.0              30449.0    2.0  15224.500000
# 130         148.0              30449.0    2.0  15224.500000
# 131          95.0              27220.0    2.0  13610.000000
# 132          21.0              27220.0    2.0  13610.000000
# 133          77.0              56871.0    3.0  18957.000000
# 134         149.0              56871.0    3.0  18957.000000
# 135         123.0              56871.0    3.0  18957.000000
# 136         105.0              24347.0    1.0  24347.000000
# 137          35.0              26148.0    1.0  26148.000000
# 138          88.0              24229.0    1.0  24229.000000
# 139          71.0              23990.0    1.0  23990.000000
# 140          20.0             113638.0    6.0  18939.666667
# 141         113.0             113638.0    6.0  18939.666667
# 142          92.0             113638.0    6.0  18939.666667
# 143          92.0             113638.0    6.0  18939.666667
# 144         140.0             113638.0    6.0  18939.666667
# 145          26.0             113638.0    6.0  18939.666667
# 146         135.0              54882.0    3.0  18294.000000
# 147          90.0              54882.0    3.0  18294.000000
# 148          84.0              54882.0    3.0  18294.000000
# 149          22.0              24845.0    1.0  24845.000000
#
# [150 rows x 4 columns]

# %%
def run_1Week():
    df10 = make_frame(10)
    df11 = make_frame(11)
    df12 = make_frame(12)
    df13 = make_frame(13)
    df14 = make_frame(14)
    df15 = make_frame(15)
    df16 = make_frame(16)
    allTogether = pd.concat([df11,df12,df13,df14,df15,df16],axis =0)
    allTogether = allTogether.groupby('Performer_ID')['perf_imp'].sum().reset_index()
#     allTogether.set_index('Performer_ID',inplace = True)
    return allTogether

def run_1Month():                            
    week1 = run_1Week()
    week2 = run_1Week()
    week3 = run_1Week()
    week4 = run_1Week()
    together = pd.concat([week1,week2,week3,week4],axis=0)
    together = together.groupby('Performer_ID')['perf_imp'].sum().reset_index()
    
    return together


def run_1Year():                            
    month1=run_1Month()
    month2=run_1Month()
    month3=run_1Month()
    month4=run_1Month()
    month5=run_1Month()
    month6=run_1Month()
    month7=run_1Month()
    month8=run_1Month()
    month9=run_1Month()
    month10=run_1Month()
    month11=run_1Month()
    month12=run_1Month()
    together = pd.concat([month1,month2,month3,month4,month5,month6,month7,month8,month9,month10,month11,month12],axis=0)
    together = together.groupby('Performer_ID')['perf_imp'].sum().reset_index()
    return together

# %%
week = run_1Week()
week.plot.hist(x='Performer_ID')
plt.xlabel("Impression Bins")
plt.title("Distribution of Impressions Across the Week")

month = run_1Month()
month.plot.hist(x='Performer_ID')
plt.xlabel("Impression Bins")
plt.title("Distribution of Impressions Across the Month")

year = run_1Year()
year.plot.hist(x='Performer_ID')
plt.xlabel("Impression Bins")
plt.title("Distribution of Impressions Across the Year")
